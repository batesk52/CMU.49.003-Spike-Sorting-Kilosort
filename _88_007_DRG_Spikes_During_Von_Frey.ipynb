# %% [markdown]
# <!-- Notebook Header Start -->
#
# <h1 align="center">Spiking Activity During Von Frey</h1>
#
# <p align="center">
#   <strong>Author:</strong> Karl Bates<br>
#   <strong>Date:</strong> 2024-11-18<br>
#   <strong>Affiliation:</strong> Carnegie Mellon University, Cohen-Karni Lab  || Neuromechatronics Lab
# </p>
#
# ---
#
#
# ## 📊 Notebook Outline
#
# * **Data Import & Preprocessing**
# * ****
#
# ## 📚 References & Additional Resources
#
# - [Kilosort4 docs](https://github.com/MouseLand/Kilosort/tree/main)
# - [SpikeInterface docs](https://github.com/SpikeInterface)
#
# ---
#
# <!-- Notebook Header End -->

# %% [markdown]
# # 📈 Importing Libraries & Data
# ---

# %% [markdown]
# ### imports

# %%
# standard imports
from pathlib import Path
import os
import pandas as pd
import numpy as np
from kilosort import io
import matplotlib.pyplot as plt

# custom imports
from automations import RM1
from automations import SpikeInterface_wrapper
from automations import Kilosort_wrapper
from automations import plots

# %% [markdown]
# ### probe definition
#
# Using the spreadsheet, `Adapter_pinout.xlsx`, the contact ID's can be traced to the "device channel", and we can assign them on the probe.
#
# In this case, our channel indices correspond to the aux inputs to the intan headstage.
#
# refer to the notebook, `RM1_pipeline.ipynb` within  the `dev_notebook` folder

# %%
# Path definitions

# save data to the inbox; make sure that the folders: binary & figures exist
SAVE_DIRECTORY = Path(fr'D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey')  # NOTE Specify the path where the data will be copied to, and where Kilosort4 results will be saved.

# in this case, the data is saved in a folder with multiple rats
DATA_DIRECTORY = Path(fr'D:\SynologyDrive\CMU.80 Data\82 External Data\82.002 Sample Rat Data from RM1 Project')  # NOTE Specify the path where the data will be copied to, and where Kilosort4 results will be saved.
# Create path if it doesn't exist
DATA_DIRECTORY.mkdir(parents=True, exist_ok=True)
SAVE_DIRECTORY.mkdir(parents=True, exist_ok=True)
PROBE_DIRECTORY = Path(r"D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.008 SpikeNeuro-Linear-32\SpikeNeuro-Linear-32.prb")

# %% [markdown]
# # 🔁 Example: Review of Every Trial in a Rat of Choice
#
# This is used to determine which trial is most likely to produce good units in a spike sorting analysis

# %% [markdown]
# ### filepath definitions

# %% [markdown]
# ### importing the rat

# %%
Rat = RM1.Rat(DATA_DIRECTORY, PROBE_DIRECTORY, "DW333")
# Out:
# Reading qsttest_1_241115_150618...
# Error reading stream 2 for qsttest_1_241115_150618: stream_id 2 is not in ['0', '1', '3', '4']
# Reading qsttest_1_241115_151239...
# Error reading stream 2 for qsttest_1_241115_151239: stream_id 2 is not in ['0', '1', '3', '4']
# Reading qsttest_1_241115_151523...
# Error reading stream 2 for qsttest_1_241115_151523: stream_id 2 is not in ['0', '1', '3', '4']
# Reading qst_1_241115_152031...
# Error reading stream 2 for qst_1_241115_152031: stream_id 2 is not in ['0', '1', '3', '4']
# Reading qst_1_241115_152346...
# Error reading stream 2 for qst_1_241115_152346: stream_id 2 is not in ['0', '1', '3', '4']
# Reading qst_1_241115_152800...
# Error reading stream 2 for qst_1_241115_152800: stream_id 2 is not in ['0', '1', '3', '4']
# Reading VF_DRG_1_241115_145120...
# Error reading stream 2 for VF_DRG_1_241115_145120: stream_id 2 is not in ['0', '1', '3', '4']
# Reading VF_DRG_1_241115_145435...
# Error reading stream 2 for VF_DRG_1_241115_145435: stream_id 2 is not in ['0', '1', '3', '4']
# Reading VF_DRG_1_241115_145739...
# Error reading stream 2 for VF_DRG_1_241115_145739: stream_id 2 is not in ['0', '1', '3', '4']
# Reading VF_DRG_4_241115_153512...
# Error reading stream 2 for VF_DRG_4_241115_153512: stream_id 2 is not in ['0', '1', '3', '4']
# Reading VF_DRG_4_241115_170440...
# Error reading stream 2 for VF_DRG_4_241115_170440: stream_id 2 is not in ['0', '1', '3', '4']

# %%
# for example, pulling the amp data from the 7th DRGS trial (only works for DW333)
# DW322.mat_files_dict["VF_DRG__145435"]["AM"]["amp"][0, 0][0, 0]

# %%
Rat.qst_experiment_notes
# Out:
# 'd1 is ttl, d2 am sync, a1 am monitor, a2 e von frey'

# %%
Rat.drgs_trial_notes.head()
# Out:
# 5            Trial Number Condition amp (uA) PW (us) Freq. (Hz) Dur. (s)  \
# Trial Number
# 1                       1       NaN      NaN     NaN        NaN      NaN
# 2                       2       NaN      NaN     NaN        NaN      NaN
# 3                       3       NaN      NaN     NaN        NaN      NaN
# 4                       4       NaN      NaN     NaN        NaN      NaN
# 5                       5       NaN      NaN     NaN        NaN      NaN
#
# 5            Stimuli Stage Stimuli Dur.  rcrtrange waitime
# Trial Number
# 1                NaN   NaN           NaN       NaN     NaN
# 2                NaN   NaN           NaN       NaN     NaN
# 3                NaN   NaN           NaN       NaN     NaN
# 4                NaN   NaN           NaN       NaN     NaN
# 5                NaN   NaN           NaN       NaN     NaN

# %%
Rat.get_sc_data()
Rat.sc_data
Rat.remove_drg_stim_window_sc()

# %% [markdown]
# ### process data for import into Kilosort
#
# I will use a combination of `SpikeInterface` & `Kilosort.io.extractors` to get the data I need

# %%
signals = SpikeInterface_wrapper(Rat, SAVE_DIRECTORY)
# Out:
# Preparing SpikeInterface wrapper for rat DW333

# %% [markdown]
# can I just make new indices in the dictionary, and only save those values? that's pretty cool!

# %%
signals.save_spinalcord_data_to_binary()
# Out:
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_150618\DW333_qsttest_1_241115_150618_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_151239\DW333_qsttest_1_241115_151239_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_151523\DW333_qsttest_1_241115_151523_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152031\DW333_qst_1_241115_152031_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152346\DW333_qst_1_241115_152346_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152800\DW333_qst_1_241115_152800_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145120\DW333_VF_DRG_1_241115_145120_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145435\DW333_VF_DRG_1_241115_145435_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145739\DW333_VF_DRG_1_241115_145739_data.bin
# Data saved to D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_4_241115_153512\DW333_VF_DRG_4_241115_153512_data.bin
# ERROR: issue importing data for VF_DRG_4_241115_170440: index 0 is out of bounds for axis 0 with size 0

# %%
spikes = Kilosort_wrapper(SAVE_DIRECTORY, PROBE_DIRECTORY)
spikes.run_kilosort_trial_summary(new_settings="vf_settings_flex_probe")
# Out:
# Preparing Kilosort wrapper for  Frey
#
# Running kilosort on qsttest_1_241115_150618
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_150618\DW333_qsttest_1_241115_150618_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.46s; total  0.46s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    10.40 %
# kilosort.run_kilosort: Memory:       20.23 %     |     25.71   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   30.19 %     |      4.83   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    15.85 %     |      2.54   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# kilosort.run_kilosort: drift computed in  1.33s; total  1.83s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    30.90 %
# kilosort.run_kilosort: Memory:       20.52 %     |     26.08   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   46.55 %     |      7.44   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.62it/s]
# kilosort.run_kilosort: 39426 spikes extracted in  0.92s; total  2.90s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.41it/s]
# kilosort.run_kilosort: 19 clusters found, in  4.72s; total  7.62s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  5.90it/s]
# kilosort.run_kilosort: 22230 spikes extracted in  0.37s; total  7.99s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    62.50 %
# kilosort.run_kilosort: Memory:       21.13 %     |     26.85   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.27 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:02<00:00,  5.37it/s]
# kilosort.run_kilosort: 15 clusters found, in  2.99s; total  10.99s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 15 units found, in  0.01s; total  11.00s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    60.00 %
# kilosort.run_kilosort: Memory:       20.85 %     |     26.50   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.27 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 5 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 11.13s = 00:00:11 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_150618\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    58.70 %
# kilosort.run_kilosort: Memory:       20.87 %     |     26.53   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.27 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_151239\DW333_qsttest_1_241115_151239_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.19s; total  0.19s
# Custom labels applied and saved for trial: qsttest_1_241115_150618
#
# Running kilosort on qsttest_1_241115_151239
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    35.80 %
# kilosort.run_kilosort: Memory:       20.87 %     |     26.52   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.27 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.51it/s]
# kilosort.run_kilosort: drift computed in  1.19s; total  1.39s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    44.60 %
# kilosort.run_kilosort: Memory:       20.72 %     |     26.33   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.27 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.56it/s]
# kilosort.run_kilosort: 36410 spikes extracted in  0.94s; total  2.48s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.41it/s]
# kilosort.run_kilosort: 19 clusters found, in  4.72s; total  7.21s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  6.13it/s]
# kilosort.run_kilosort: 20801 spikes extracted in  0.37s; total  7.58s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    69.20 %
# kilosort.run_kilosort: Memory:       20.98 %     |     26.66   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:02<00:00,  7.89it/s]
# kilosort.run_kilosort: 14 clusters found, in  2.04s; total  9.63s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 13 units found, in  0.01s; total  9.64s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    62.10 %
# kilosort.run_kilosort: Memory:       20.83 %     |     26.48   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 2 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 9.75s = 00:00:10 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_151239\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    59.30 %
# kilosort.run_kilosort: Memory:       20.86 %     |     26.51   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_151523\DW333_qsttest_1_241115_151523_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.16s; total  0.16s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    44.70 %
# kilosort.run_kilosort: Memory:       20.85 %     |     26.50   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# Custom labels applied and saved for trial: qsttest_1_241115_151239
#
# Running kilosort on qsttest_1_241115_151523
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.59it/s]
# kilosort.run_kilosort: drift computed in  1.11s; total  1.29s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    15.00 %
# kilosort.run_kilosort: Memory:       20.68 %     |     26.28   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.56it/s]
# kilosort.run_kilosort: 32547 spikes extracted in  0.93s; total  2.37s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.66it/s]
# kilosort.run_kilosort: 20 clusters found, in  4.40s; total  6.76s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  5.52it/s]
# kilosort.run_kilosort: 17702 spikes extracted in  0.39s; total  7.16s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    75.00 %
# kilosort.run_kilosort: Memory:       21.04 %     |     26.75   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:00<00:00, 16.92it/s]
# kilosort.run_kilosort: 16 clusters found, in  0.95s; total  8.12s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 14 units found, in  0.01s; total  8.13s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    59.40 %
# kilosort.run_kilosort: Memory:       20.76 %     |     26.38   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 4 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 8.23s = 00:00:8 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qsttest_1_241115_151523\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    68.60 %
# kilosort.run_kilosort: Memory:       20.76 %     |     26.39   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152031\DW333_qst_1_241115_152031_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.12s; total  0.12s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    52.90 %
# kilosort.run_kilosort: Memory:       20.76 %     |     26.38   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# Custom labels applied and saved for trial: qsttest_1_241115_151523
#
# Running kilosort on qst_1_241115_152031
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.46it/s]
# kilosort.run_kilosort: drift computed in  1.12s; total  1.25s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    20.80 %
# kilosort.run_kilosort: Memory:       20.60 %     |     26.18   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.56it/s]
# kilosort.run_kilosort: 34867 spikes extracted in  0.94s; total  2.33s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.83it/s]
# kilosort.run_kilosort: 23 clusters found, in  4.21s; total  6.54s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# kilosort.run_kilosort: 23841 spikes extracted in  0.51s; total  7.05s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    50.00 %
# kilosort.run_kilosort: Memory:       20.95 %     |     26.63   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:01<00:00,  9.38it/s]
# kilosort.run_kilosort: 19 clusters found, in  1.71s; total  8.77s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 18 units found, in  0.01s; total  8.79s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    67.20 %
# kilosort.run_kilosort: Memory:       20.67 %     |     26.27   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 4 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 8.89s = 00:00:9 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152031\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    56.20 %
# kilosort.run_kilosort: Memory:       20.68 %     |     26.29   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152346\DW333_qst_1_241115_152346_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.16s; total  0.16s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    42.80 %
# kilosort.run_kilosort: Memory:       20.68 %     |     26.29   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# Custom labels applied and saved for trial: qst_1_241115_152031
#
# Running kilosort on qst_1_241115_152346
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.55it/s]
# kilosort.run_kilosort: drift computed in  1.11s; total  1.29s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    20.30 %
# kilosort.run_kilosort: Memory:       20.52 %     |     26.08   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.57it/s]
# kilosort.run_kilosort: 28292 spikes extracted in  0.94s; total  2.36s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.52it/s]
# kilosort.run_kilosort: 21 clusters found, in  4.58s; total  6.94s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
# kilosort.run_kilosort: 19435 spikes extracted in  0.41s; total  7.35s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    54.20 %
# kilosort.run_kilosort: Memory:       20.93 %     |     26.60   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:01<00:00,  8.20it/s]
# kilosort.run_kilosort: 16 clusters found, in  1.96s; total  9.32s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 14 units found, in  0.01s; total  9.33s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    65.20 %
# kilosort.run_kilosort: Memory:       20.65 %     |     26.25   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 3 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 9.42s = 00:00:9 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152346\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    61.60 %
# kilosort.run_kilosort: Memory:       20.67 %     |     26.27   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152800\DW333_qst_1_241115_152800_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.17s; total  0.17s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    45.60 %
# kilosort.run_kilosort: Memory:       20.68 %     |     26.28   /   127.10 GB
# Custom labels applied and saved for trial: qst_1_241115_152346
#
# Running kilosort on qst_1_241115_152800
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.50it/s]
# kilosort.run_kilosort: drift computed in  1.10s; total  1.28s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    39.60 %
# kilosort.run_kilosort: Memory:       20.55 %     |     26.11   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.55it/s]
# kilosort.run_kilosort: 36481 spikes extracted in  0.96s; total  2.38s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.43it/s]
# kilosort.run_kilosort: 24 clusters found, in  4.69s; total  7.07s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  3.27it/s]
# kilosort.run_kilosort: 21994 spikes extracted in  0.65s; total  7.72s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    69.60 %
# kilosort.run_kilosort: Memory:       20.72 %     |     26.34   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:01<00:00, 11.41it/s]
# kilosort.run_kilosort: 20 clusters found, in  1.41s; total  9.15s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 19 units found, in  0.01s; total  9.16s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    63.60 %
# kilosort.run_kilosort: Memory:       20.63 %     |     26.22   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 4 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 9.26s = 00:00:9 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\qst_1_241115_152800\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    57.20 %
# kilosort.run_kilosort: Memory:       20.64 %     |     26.23   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145120\DW333_VF_DRG_1_241115_145120_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.10s; total  0.10s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    51.10 %
# kilosort.run_kilosort: Memory:       20.64 %     |     26.23   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# Custom labels applied and saved for trial: qst_1_241115_152800
#
# Running kilosort on VF_DRG_1_241115_145120
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.53it/s]
# kilosort.run_kilosort: drift computed in  1.09s; total  1.20s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    12.80 %
# kilosort.run_kilosort: Memory:       20.49 %     |     26.04   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.55it/s]
# kilosort.run_kilosort: 17794 spikes extracted in  0.95s; total  2.29s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.76it/s]
# kilosort.run_kilosort: 16 clusters found, in  4.27s; total  6.56s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# kilosort.run_kilosort: 14639 spikes extracted in  0.54s; total  7.10s
# ...
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 2 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 9.57s = 00:00:10 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145435\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    55.20 %
# kilosort.run_kilosort: Memory:       20.62 %     |     26.21   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145739\DW333_VF_DRG_1_241115_145739_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# kilosort.run_kilosort: Preprocessing filters computed in  0.16s; total  0.17s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    42.00 %
# Custom labels applied and saved for trial: VF_DRG_1_241115_145435
#
# Running kilosort on VF_DRG_1_241115_145739
# kilosort.run_kilosort: Memory:       20.62 %     |     26.20   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.53it/s]
# kilosort.run_kilosort: drift computed in  1.19s; total  1.37s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    19.90 %
# kilosort.run_kilosort: Memory:       20.47 %     |     26.02   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.57it/s]
# kilosort.run_kilosort: 24340 spikes extracted in  0.99s; total  2.50s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.62it/s]
# kilosort.run_kilosort: 20 clusters found, in  4.44s; total  6.94s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  3.63it/s]
# kilosort.run_kilosort: 26346 spikes extracted in  0.58s; total  7.52s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    75.00 %
# kilosort.run_kilosort: Memory:       20.87 %     |     26.53   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:03<00:00,  5.12it/s]
# kilosort.run_kilosort: 16 clusters found, in  3.13s; total  10.66s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 16 units found, in  0.01s; total  10.68s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    62.30 %
# kilosort.run_kilosort: Memory:       20.61 %     |     26.19   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 2 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 10.81s = 00:00:11 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_1_241115_145739\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    66.70 %
# kilosort.run_kilosort: Memory:       20.61 %     |     26.19   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: Kilosort version 4.0.30
# kilosort.run_kilosort: Python version 3.9.21
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: Windows-10-10.0.26100-SP0 AMD64
# kilosort.run_kilosort: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# kilosort.run_kilosort: Using GPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: Using CUDA device: NVIDIA GeForce RTX 4070 Ti SUPER 15.99GB
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_4_241115_153512\DW333_VF_DRG_4_241115_153512_data.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: N samples: 2100000
# kilosort.run_kilosort: N seconds: 70.0
# kilosort.run_kilosort: N batches: 2
# Custom labels applied and saved for trial: VF_DRG_1_241115_145739
#
# Running kilosort on VF_DRG_4_241115_153512
# kilosort.run_kilosort: Preprocessing filters computed in  0.28s; total  0.28s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after preprocessing
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    28.60 %
# kilosort.run_kilosort: Memory:       20.60 %     |     26.19   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing drift correction.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.53it/s]
# kilosort.run_kilosort: drift computed in  1.16s; total  1.46s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after drift correction
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    23.60 %
# kilosort.run_kilosort: Memory:       20.45 %     |     25.99   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using templates
# kilosort.run_kilosort: ----------------------------------------
# kilosort.spikedetect: Re-computing universal templates from data.
# kilosort.spikedetect: Number of universal templates: 63
# kilosort.spikedetect: Detecting spikes...
# 100%|██████████| 2/2 [00:00<00:00,  2.58it/s]
# kilosort.run_kilosort: 23963 spikes extracted in  1.01s; total  2.60s
# kilosort.run_kilosort:
# kilosort.run_kilosort: First clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:04<00:00,  3.78it/s]
# kilosort.run_kilosort: 24 clusters found, in  4.27s; total  6.86s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Extracting spikes using cluster waveforms
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 2/2 [00:00<00:00,  3.55it/s]
# kilosort.run_kilosort: 38678 spikes extracted in  0.59s; total  7.46s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after spike detection
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    66.70 %
# kilosort.run_kilosort: Memory:       20.87 %     |     26.53   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Final clustering
# kilosort.run_kilosort: ----------------------------------------
# 100%|██████████| 16/16 [00:03<00:00,  4.19it/s]
# kilosort.run_kilosort: 23 clusters found, in  3.83s; total  11.30s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Merging clusters
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 22 units found, in  0.01s; total  11.32s
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after clustering
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    60.50 %
# kilosort.run_kilosort: Memory:       20.60 %     |     26.19   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort:
# kilosort.run_kilosort: Saving to phy and computing refractory periods
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: 8 units found with good refractory periods
# kilosort.run_kilosort: Total runtime: 11.47s = 00:00:11 h:m:s
# kilosort.run_kilosort: Sorting output saved in: D:\SynologyDrive\CMU.80 Data\88 Analyzed Data\88.007 DRG Spikes during Von Frey\binary\VF_DRG_4_241115_153512\kilosort4.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Resource usage after saving
# kilosort.run_kilosort: ********************************************************
# kilosort.run_kilosort: CPU usage:    71.70 %
# kilosort.run_kilosort: Memory:       20.63 %     |     26.22   /   127.10 GB
# kilosort.run_kilosort: ------------------------------------------------------
# kilosort.run_kilosort: GPU usage:    `conda install pynvml` for GPU usage
# kilosort.run_kilosort: GPU memory:   53.28 %     |      8.52   /    15.99 GB
# kilosort.run_kilosort: Allocated:     0.05 %     |      0.01   /    15.99 GB
# kilosort.run_kilosort: Max alloc:    25.58 %     |      4.09   /    15.99 GB
# kilosort.run_kilosort: ********************************************************
# Custom labels applied and saved for trial: VF_DRG_4_241115_153512
