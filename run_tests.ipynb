# %% [markdown]
# # run standard tests before releasing features:

# %%
import pytest
pytest.main([r'tests\test_von_frey_analysis.py'])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.21, pytest-8.3.5, pluggy-1.5.0
# rootdir: c:\Users\Karl\Documents\_Python\CMU.49.003-Spike-Sorting-Kilosort
# configfile: pytest.ini
# plugins: anyio-4.8.0
# collected 1 item
#
# tests\test_von_frey_analysis.py F                                        [100%]
#
# ================================== FAILURES ===================================
# _____________________________ test_full_pipeline ______________________________
#
# self = Index([1, 5, 'dummy'], dtype='object', name=5), key = 'Trial Number'
#
#     def get_loc(self, key):
#         """
#         Get integer location, slice or boolean mask for requested label.
#
#         Parameters
#         ----------
#         key : label
#
#         Returns
#         -------
#         int if unique index, slice if monotonic index, else mask
#
#         Examples
#         --------
# ...
